# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import IsolationForest
import time
import rrcf
sns.set_style("whitegrid")

# %%
IF = IsolationForest(n_estimators = 200,
                     max_samples  = 1000,
                     contamination= 'auto',
                     behaviour='new',
                     random_state=42)

# %%
data = np.load("taxi_all.npz")

parmas = {"trees"      : 100,
         "sample_size" : 1000,
         "data_dim"    : 48}

D = np.zeros((len(data["passengers"]), 48))
for i in range(48, len(data["passengers"])):
    D[i,:] = data["passengers"][i-48:i]

# %%
IF.fit(D)
# Out:
# IsolationForest(behaviour='new', bootstrap=False, contamination='auto',
#         max_features=1.0, max_samples=1000, n_estimators=200, n_jobs=None,
#         random_state=42, verbose=0)

# %%
score = IF.score_samples(D)

# %%
plt.plot(-score)
